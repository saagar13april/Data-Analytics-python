# %%
from dputils.scrape import Scraper , Tag

# %%
sc = Scraper ('https://www.sarkariresult.com/')

# %%
print(sc.soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>SarkariResult.com : Sarkari Results, Latest Online Form | Result 2023</title>
# <meta content="Sarkari Result, Sarkari Results : SarkariResult.com provides latest Sarkari Result Jobs, Online Form, Sarkari Naukri Result in Sarkari Result 2023 various sectors such as Railway, Bank, SSC, Navy, Police, UPPSC, UPSSSC, UPTET, UP Scholarship and other sarkari result Com alerts at one place सरकारी रिजल्ट  " name="description"/>
# <meta content="Sarkari Result, Sarkari Results, sarkari result 2023,  latest sarkari result, Sarkariresult, Sarkari, Sarkariresults, Sarkari Naukri, sarkari results 2023, sarkari result 2023, Sarkari Exam, SarkariResult.com" name="keywords"/>
# <meta content="general" name="rating">
# <meta content="en" http-equiv="content-language">
# <meta content="global" name="distribution">
# <meta content="index, follow" name="robots"/>
# ...

# %%
sc.soup.title
# Out:
# <title>SarkariResult.com : Sarkari Results, Latest Online Form | Result 2023</title>

# %%
sc.soup.find_all('a')
# Out:
# [<a href="https://www.sarkariresult.com/">Home</a>,
#  <a href="https://www.sarkariresult.com/latestjob/">Latest Jobs</a>,
#  <a href="https://www.sarkariresult.com/result/">Results</a>,
#  <a href="https://www.sarkariresult.com/admitcard/">Admit Card</a>,
#  <a href="https://www.sarkariresult.com/answerkey/">Answer Key</a>,
#  <a href="https://www.sarkariresult.com/syllabus/">Syllabus</a>,
#  <a href="https://www.sarkariresult.com/search/">Search</a>,
#  <a href="https://www.sarkariresult.com/contactus/">Contact Us</a>,
#  <a href="https://play.google.com/store/apps/details?id=com.app.app14f269771c01" target="_blank"><b><font size="4">Sarkari Result Android Apps</font></b></a>,
#  <a href="https://www.youtube.com/c/SarkariResultOfficial" target="_blank"><b><font size="4">Sarkari Result Youtube Channel</font></b></a>,
# ...
